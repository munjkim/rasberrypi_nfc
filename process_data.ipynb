# %%
# 김시원, 박태준, 전선우, 정혜진, 강동원, 고묘정, 박은혜, 최가영, 최재영, 장민구

# %%
import pandas as pd
import datetime
import numpy as np

# %%
df_ID = pd.read_csv('./data/student.csv')
df_data = pd.read_csv('./data/reading.csv')
df = pd.DataFrame()

# %%
df_ID
# Out:
#      Student ID Name
# 0     202422005  김문정
# 1     202422022  백민혁
# 2     202428009  마상균
# 3     202111014  김건호
# 4     201811063  박영석
# ..          ...  ...
# 157   202311144  이종경
# 158   202311017  김다영
# 159   202311156  장민구
# 160   202311104  안서연
# 161   202443005  김승섭
#
# [162 rows x 2 columns]

# %%
df['Student ID'] = ['None'] * len(df_ID)
df['Name'] = ['None'] * len(df_ID)
df['UID'] = ['None'] * len(df_ID)

for i in range(len(df_ID)):
    sid = df_ID['Student ID'][i]
    name = df_ID.loc[df_ID['Student ID']==sid, 'Name'].values[0]

    try:
        uid = df_data.loc[df_data['Student ID']==sid, 'UID'].values[0]
    except IndexError:
        uid = None

    df['Student ID'][i] = sid
    df['Name'][i] = name
    df['UID'][i] = uid

    print(sid, name, uid)

df.to_csv('./data/data.csv')
# Out:
# 202422005 김문정 fd  b0  34  c5
# 202422022 백민혁 87  f3  c7  5c
# 202428009 마상균 5d  9e  33  c5
# 202111014 김건호 None
# 201811063 박영석 22  3b  a8  e5
# 201811028 김승현 42  8b  b0  e5
# 201911048 노민성 b3  d9  5d  b5
# 201911159 정회성 4e  38  23  14
# 201911165 조윤성 37  69  8c  5c
# 201911090 안정후 ab  3e  d7  4e
# 201911162 조상우 13  5b  5e  b5
# 201911157 정해익 d3  14  67  b5
# 201911185 추성재 83  d6  64  b5
# 202011056 김종진 43  4e  5e  b5
# 202011086 박재민 92  d3  af  e5
# 202011102 서지원 d2  3f  b0  e5
# 202011187 장믿음 82  48  b0  e5
# 202011052 김웅기 e3  18  5c  b5
# 202011118 엄유성 22  51  b0  e5
# 202011103 성민승 2b  18  d2  4d
# 202011120 오상규 b3  81  63  b5
# 202011048 김시원 7c  97  c1  dd
# 202011091 박태준 b7  51  c8  5c
# 202011094 박현우 73  bc  64  b5
# 202011100 백지훈 fe  e2  20  14
# 202111164 정다현 b7  4b  c5  5c
# 202111058 문수민 83  2e  60  b5
# 202111170 정윤중 0d  d0  f7  c4
# 202111061 박규현 d3  e0  5f  b5
# 202111107 양민우 43  81  61  b5
# 202111012 권병준 d3  98  5f  b5
# 202111051 남도혁 e2  31  ae  e5
# 202111024 김미송 23  ae  67  b5
# 202111139 이유석 13  d6  60  b5
# 202111119 윤경훈 d3  1a  67  b5
# 202111038 김재환 f2  68  ac  e5
# 202111021 김도훈 b3  4d  60  b5
# 202111079 박진홍 d3  8c  5d  b5
# 202111085 백원중 c2  35  af  e5
# 202111033 김신욱 e2  06  ab  e5
# 202111163 정기용 b3  cd  5b  b5
# 202111124 이건하 13  b5  5b  b5
# 202111122 윤태인 d3  bf  62  b5
# 202111125 이기헌 93  e2  61  b5
# 202111104 안위수 b3  8a  62  b5
# 202111008 곽도영 43  4d  25  ae
# 202111022 김동현 d3  c9  62  b5
# 202111141 이재진 43  12  68  b5
# 202111060 박건우 43  99  66  b5
# 202211071 마서진 03  9b  24  ae
# 202211076 박나영 3b  03  ec  4d
# 202211206 최재영 0b  42  9e  4e
# 202211214 최효빈 3b  05  82  4e
# 202211036 김여진 8b  af  1f  4e
# 202211090 백현석 f7  81  c4  5c
# 202211222 황지영 9b  7b  d5  4e
# 202211194 조형윤 db  ee  9b  4e
# 202211219 홍지수 6b  81  43  4e
# 202211094 서정규 c7  ec  c4  5c
# 202211059 나해람 03  be  5f  b5
# 202211103 신상은 eb  e0  c1  4e
# 202211046 김정민 e3  2b  63  b5
# 202211016 김나현 c3  a0  63  b5
# 202211017 김나혜 f3  35  5e  b5
# 202211152 이준 5b  c8  08  4e
# 202211187 정해주 fb  80  64  4e
# 202211044 김은송 93  11  5e  b5
# 202211056 김호병 8b  3e  de  4e
# 202211112 양슬아 7b  a3  ad  4e
# 202211083 박준수 b7  ba  c0  5c
# 202211052 김현민 f3  07  68  b5
# 202211142 이연수 e6  c4  33  04
# 202211195 조후연 c6  f5  32  04
# 202211075 박근희 ed  ed  03  c5
# 202211210 최준호 fd  31  00  c5
# 202211099 송유진 9b  69  16  4e
# 202211053 김현수 03  e9  60  b5
# 202211020 김동현 53  78  65  b5
# 202211193 조현준 06  d9  33  04
# 202323010 정상헌 db  82  f2  4d
# 202311155 임정민 97  2b  88  5c
# 202311051 김예원 d7  c7  c0  5c
# 202311044 김선규 b7  41  c1  5c
# 202311140 이윤호 db  dc  23  4e
# 202311129 이민규 ab  e0  d6  4e
# 202311170 정혜진 67  80  c0  5c
# 202311088 박재현 bb  bf  a4  4e
# 202311181 조한준 0b  98  1c  4e
# 202311098 서주혁 1b  3b  61  4e
# 202311206 허준서 27  f7  b5  5c
# 202311037 김범수 57  4a  9f  5c
# 202311019 김도윤 c7  48  88  5c
# 202311001 강동원 97  9f  a2  5c
# 202311182 조형준 cb  42  04  4e
# 202311025 김동현 d7  6a  cb  5c
# 202311180 조준호 eb  47  fe  4d
# 202311132 이상아 2b  9a  d0  4e
# 202311165 전준서 27  85  cb  5c
# 202311131 이상민 a6  e2  31  04
